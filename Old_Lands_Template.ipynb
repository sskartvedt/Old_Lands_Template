# | LAKE  |6409    |
# | PARA  |6409    |
#
# </details><br>
#
# <details>
# <summary><mark>California</mark>
# </summary>
#
# | Alpha | WKID   |
# |-------|-------------|
# | 	BLPA	  |	6420 	     |
# | 	CABR	  |	6426	     |
# | 	CAMO	  |	6424	     |
# | 	CECH	  |	6424	     |
# | 	CHIS	  |	6424	     |
# | 	DEPO	  |	6420	     |
# | 	DEVA	  |	6422/6424	 |
# | 	EUON	  |	6420 	     |
# | 	FOPO	  |	6420 	     |
# | 	GOGA	  |	6420 	     |
# | 	JOMU	  |	6420 	     |
# | 	JOTR	  |	6424/6426	 |
# | 	KICA	  |	6422	     |
# | 	LABE	  |	6416	     |
# | 	LAVO	  |	6416	     |
# | 	MANZ	  |	6422	     |
# | 	MOJA	  |	6424	     |
# | 	MUWO	  |	6420 	     |
# | 	PINN	  |	6422	     |
# | 	POCH	  |	6420 	     |
# | 	PORE	  |	6420 	     |
# | 	REDW	  |	6416	     |
# | 	RORI	  |	6420 	     |
# | 	SAFR	  |	6420 	     |
# | 	SAMO	  |	6424	     |
# | 	YOSE	  |	6420 	     |
# | 	SEKI	  |	6422	     |
# | 	TULE	  |	6416	     |
# | 	WHIS	  |	6416	     |
# | 	YOSE	  |	6420 	     |
#
#
# </details><br>
#
# <details>
# <summary><mark>Hawaii</mark>
# </summary>
#
# | Alpha | WKID   |
# |-------|-------------|
# | 	ALCA	  |	102525	|
# | 	HALE	  |	102526	|
# | 	HAVO	  |	102525	|
# | 	HONO	  |	6633	|
# | 	KAHO	  |	102525	|
# | 	KALA	  |	102526	|
# | 	PERL	  |	6633	|
# | 	PUHE	  |	102525	|
# | 	PUHO	  |	102525	|
#
#
# </details><br>
#
# <details>
# <summary><mark>Idaho</mark>
# </summary>
#
# | Alpha | WKID   |
# |-------|-------------|
# | 	CIRO	  |	6449	|
# | 	CRMO	  |	6449/6451	|
# | 	HAFO	  |	6449	|
# | 	MIIN	  |	6449	|
# | 	NEPE	  |	MULTI	|
#
#
# </details><br>
#
# <details>
# <summary><mark>Montana</mark>
# </summary>
#
# | Alpha | WKID   |
# |-------|-------------|
# | 	BIHO	  |	2901	|
#
#
# </details><br>
#
# <details>
# <summary><mark>Nevada</mark>
# </summary>
#
# | Alpha | WKID   |
# |-------|-------------|
# | 	AVKW	  |	6521 	|
# | 	DEVA	  |	6519/6523	|
# | 	GRBA	  |	6521	|
# | 	LAKE	  |	6521	|
# | 	TUSK	  |	6521	|
#
#
# </details><br>
#
# <details>
# <summary><mark>Oregon</mark>
# </summary>
#
# | Alpha | WKID   |
# |-------|-------------|
# | 	CRLA	  |	6561	|
# | 	FOVA	  |	6559	|
# | 	JODA	  |	6559	|
# | 	LEWI	  |	6559	|
# | 	ORCA	  |	6561	|
#
#
# </details><br>
#
# <details>
# <summary><mark>Washington</mark>
# </summary>
#
# | Alpha | WKID   |
# |-------|-------------|
# | 	EBLA	  |	6597	|
# | 	FOVA	  |	6599	|
# | 	KLSE	  |	6597	|
# | 	LACH	  |	6597	|
# | 	LARO	  |	6597	|
# | 	LEWI	  |	6599	|
# | 	MIIN	  |	6597	|
# | 	MORA	  |	6599	|
# | 	MAPR	  |	6599	|
# | 	NOCA	  |	6597	|
# | 	OLYM	  |	6597/6599	|
# | 	ROLA	  |	6597	|
# | 	SAJH	  |	6597	|
# | 	WHMI	  |	6599	|
#
#
# </details><br>
#
# <details>
# <summary><mark>Pacific/Other</mark>
# </summary>
#
# | Alpha | WKID   |
# |-------|-------------|
# | 	AMME	| 	32654	|
# | 	IAFL	| 	MULTI	|
# | 	NPSA	| 	32702	|
# | 	WAPA	| 	102766	|
#
#
# </details><br>
#
# </details>

# %% [markdown]
# # Enter User Defined Variables
#    - Park ALPHA
#    - areaID
#    - Spatial Reference(WKID)

# %%
alpha = "GOGA"
areaID = "332"
WKID = int(6420)


srs = arcpy.SpatialReference (WKID) # leading zeros with FIPS code a problem
# Use display name, WKID or projection file (examples below):
#srs = arcpy.SpatialReference ("NAD 1983 (2011) StatePlane California V FIPS 0405 (US Feet)")
#srs = arcpy.SpatialReference ("c:/coordsystems/CA_SPZ5_NAD_2011.prj")
#srs = arcpy.SpatialReference (6318) #NAD 1983 (2011) Contiguous USA Albers

# %% [markdown]
# # Import modules

# %%
# Import system modules
import os
import sys
import time
import arcpy
from arcpy import metadata as md

arcpy.env.overwriteOutput = True

# %% [markdown]
# # Generate Other Variables

# %%
# Generate Other Variables
unitCode =  alpha.upper()
aprx = arcpy.mp.ArcGISProject("CURRENT")
dbPath = aprx.homeFolder

# Tool parameter accessed with GetParameterAsText
#dbPath = arcpy.GetParameterAsText(0)
#srs = arcpy.GetParameterAsText(1)
#alpha = arcpy.GetParameterAsText(2)
#areaID = arcpy.GetParameterAsText(3)
#unitCode =  alpha.upper()

# %% [markdown]
# # Create Feature Class Names

# %%
# Feature class names
start_time = time.time()

Annotation_ln = unitCode + "_Annotation_ln"
Annotation_pt = unitCode + "_Annotation_pt"
Boundary_py = unitCode + "_Boundary_py"
LegisHist_ln = unitCode + "_LegisHist_ln"
LegisHist_py = unitCode + "_LegisHist_py"
Notes_pt = unitCode + "_Notes_pt"
SubsurfOwn_py = unitCode + "_SubsurfOwn_py"
SurfaceOwn_py = unitCode + "_SurfaceOwn_py"
Survey_py = unitCode + "_Survey_py"
SurveyBndy_ln = unitCode + "_COGO_SurveyBndy_ln"
SurveyMon_pt = unitCode + "_SurveyMon_pt"
Tracts_py = unitCode + "_Tracts_py"
TractsBndy_ln = unitCode + "_TractsBndy_ln"
UseLocations_pt = unitCode + "_UseLocations_pt"
UseLocations_py = unitCode + "_UseLocations_py"
UseLocations_ln = unitCode + "_COGO_UseLocations_ln"

# Database and path name variables
dbName = unitCode + "_Template"
thisDB = dbPath+"\\"+dbName+".gdb"
fdName = unitCode + "_Features"
FD = thisDB + "\\"+fdName

# Report elapsed time
for i in range(100000):
    i*i
elapsed_time = time.time() - start_time
minutes = elapsed_time // 60
seconds = elapsed_time % 60
print(f"This code block took {int(minutes)} minutes and {seconds:.2f} seconds to run")
# Out:
# This code block took 0 minutes and 0.00 seconds to run

# %% [markdown]
# # Create Filegdb

# %%
# Check for existence of the feature dataset

# If the output feature class already exists, raise an error
if arcpy.Exists(thisDB):
    # Raise ExecuteError    
    arcpy.AddError(thisDB + " already exists...")
    raise arcpy.ExecuteError
else:
    pass

# %%
# Use this if you want to create feature dataset in a new geodatabase
# Create file geodatabase
arcpy.CreateFileGDB_management(dbPath, dbName)

# Set environment settings
arcpy.env.workspace = thisDB

# %% [markdown]
# # Create Domains

# %%
# Domains
# BNDYTYPE_LANDS2022 domain
# Domain name
start_time = time.time()

domainName = "DOM_ANNOTYPE_LANDS2022"

# Domain description
domainDescription = "Annotation Types"

# Domain values
domainValues = {
"Easement":"Easement",
"Hydro":"Hydro",
"Line - Hook":"Line - Hook",
"Line - Leader":"Line - Leader",
"Lot/Parcel ":"Lot/Parcel ",
"Park  - Historic Legislated":"Park  - Historic Legislated",
"Park  - Legislated":"Park  - Legislated",
"Park  - Proposed":"Park  - Proposed",
"Plat Subdivision ":"Plat Subdivision ",
"PLSS Section ":"PLSS Section ",
"PLSS Section Subdivision ":"PLSS Section Subdivision ",
"PLSS Township/Range ":"PLSS Township/Range ",
"Road":"Road",
"Survey Tie Line":"Survey Tie Line",
"Tract  - Disposal":"Tract  - Disposal",
"Tract  - Mineral":"Tract  - Mineral",
"Tract - Primary Fee":"Tract - Primary Fee",
"Tract - Primary Less Than Fee":"Tract - Primary Less Than Fee",
"Tract - Secondary Fee":"Tract - Secondary Fee",
"Tract - Secondary Less Than Fee ":"Tract - Secondary Less Than Fee ",
"Wilderness  - Official":"Wilderness  - Official",
"Not Identified":"Not Identified",
"Other":"Other"
}

arcpy.CreateDomain_management(thisDB, domainName, domainDescription, "TEXT", "CODED")
for code in  domainValues:
    arcpy.AddCodedValueToDomain_management(thisDB, domainName, code, domainValues[code])

# BNDYTYPE_LANDS2022 domain
# Domain name
domainName = "DOM_BNDYTYPE_LANDS2022"

# Domain description
domainDescription = "Boundary line identifier for display"

# Domain values
domainValues = {
"Easement Center Line":"Easement Center Line",
"Easement Edge":"Easement Edge",
"Lot/Block/Parcel Boundary":"Lot/Block/Parcel Boundary",
"Park Boundary - Historic Legislated":"Park Boundary - Historic Legislated",
"Park Boundary - Legislated":"Park Boundary - Legislated",
"Park Boundary - Proposed":"Park Boundary - Proposed",
"Plat Subdivision Boundary":"Plat Subdivision Boundary",
"PLSS Section Boundary":"PLSS Section Boundary",
"PLSS Section Subdivision Boundary":"PLSS Section Subdivision Boundary",
"PLSS Township/Range Boundary":"PLSS Township/Range Boundary",
"Survey Tie Line":"Survey Tie Line",
"Tract Boundary - Disposal":"Tract Boundary - Disposal",
"Tract Boundary - Mineral":"Tract Boundary - Mineral",
"Tract Boundary - Primary":"Tract Boundary - Primary",
"Tract Boundary - Secondary":"Tract Boundary - Secondary",
"Wilderness Boundary - Official":"Wilderness Boundary - Official",
"Not Identified":"Not Identified",
"Other":"Other"
}

arcpy.CreateDomain_management(thisDB, domainName, domainDescription, "TEXT", "CODED")
for code in  domainValues:
    arcpy.AddCodedValueToDomain_management(thisDB, domainName, code, domainValues[code])
    
# DOM_DATAACCESS_NPS2016 domain
# Domain name
domainName = "DOM_DATAACCESS_NPS2016"

# Domain description
domainDescription = "Data access restrictions"

# Domain values
domainValues = {
"Unrestricted":"Unrestricted",
"Internal NPS Only":"Internal NPS Only",
"Secure Access Only":"Secure Access Only"
}
arcpy.CreateDomain_management(thisDB, domainName, domainDescription, "TEXT", "CODED")
for code in  domainValues:
    arcpy.AddCodedValueToDomain_management(thisDB, domainName, code, domainValues[code])

# DOM_USETYPE_LANDS2022 domain
# Domain name
domainName = "DOM_USETYPE_LANDS2022"

# Domain description
domainDescription = "General use type"

# Domain values
domainValues = {
"Conservation/Scenic":"Conservation/Scenic",
"Drainage":"Drainage",
"Ingress/Egress/Access":"Ingress/Egress/Access",
"Multiple Uses":"Multiple Uses",
"Trail":"Trail",
"Utility":"Utility",
"Not Identified":"Not Identified",
"Other":"Other"
}
arcpy.CreateDomain_management(thisDB, domainName, domainDescription, "TEXT", "CODED")
for code in  domainValues:
    arcpy.AddCodedValueToDomain_management(thisDB, domainName, code, domainValues[code])

# DOM_ISEXTANT_NPS2016 domain
# Domain name
domainName = "DOM_ISEXTANT_NPS2016"

# Domain description
domainDescription = "The condition/status of the survey monument"

# Domain values
domainValues = {
"True":"True",
"False":"False",
"Unknown":"Unknown",
"Partial":"Partial"
}
arcpy.CreateDomain_management(thisDB, domainName, domainDescription, "TEXT", "CODED")
for code in  domainValues:
    arcpy.AddCodedValueToDomain_management(thisDB, domainName, code, domainValues[code])

# DOM_MAINTAINER_NPS2021 domain
# Domain name
domainName = "DOM_MAINTAINER_NPS2021"

# Domain description
domainDescription = "List of Departments/Bureaus/Others"

# Domain values
domainValues = {
"National Park Service":"National Park Service",
"Bureau of Indian Affairs":"Bureau of Indian Affairs",
"Bureau of Land Management":"Bureau of Land Management",
"Bureau of Reclamation":"Bureau of Reclamation",
"County, Parish, Borough":"County, Parish, Borough",
"Department of Defense":"Department of Defense",
"Department of Energy":"Department of Energy",
"Federal Aviation Administration":"Federal Aviation Administration",
"Federal Highway Administration":"Federal Highway Administration",
"Fish and Wildlife Service":"Fish and Wildlife Service",
"Forest Service":"Forest Service",
"Local Government":"Local Government",
"Other Federal Agency":"Other Federal Agency",
"Private":"Private",
"State":"State",
"Tribal":"Tribal",
"US Army Corps of Engineers":"US Army Corps of Engineers",
"US Geological Survey":"US Geological Survey",
"Unknown":"Unknown",
"Not Applicable":"Not Applicable"
}
arcpy.CreateDomain_management(thisDB, domainName, domainDescription, "TEXT", "CODED")
for code in  domainValues:
    arcpy.AddCodedValueToDomain_management(thisDB, domainName, code, domainValues[code])

# DOM_MAPMETHOD_LANDS2022 domain
# Domain name
domainName = "DOM_MAPMETHOD_LANDS2022"

# Domain description
domainDescription = "Method by which data is entered and created"

# Domain values
domainValues = {
"COGO":"COGO",
"Digitized":"Digitized",
"Feature Extraction":"Feature Extraction",
"Surveyed/GPS/Geodetically Derived":"Surveyed/GPS/Geodetically Derived",
"Unknown":"Unknown",
"Other":"Other"
}
arcpy.CreateDomain_management(thisDB, domainName, domainDescription, "TEXT", "CODED")
for code in  domainValues:
    arcpy.AddCodedValueToDomain_management(thisDB, domainName, code, domainValues[code])
    
# DOM_MAPSOURCE_LANDS2022 domain
# Domain name
domainName = "DOM_MAPSOURCE_LANDS2022"

# Domain description
domainDescription = "Primary data source"

# Domain values
domainValues = {
"Document - Agreement/MOU":"Document - Agreement/MOU",
"Document - Civil Action":"Document - Civil Action",
"Document - Deed":"Document - Deed",
"Document - Easement":"Document - Easement",
"Document - Field notes":"Document - Field notes",
"Document - Legislation":"Document - Legislation",
"Document - Master title plat":"Document - Master title plat",
"Document - Patent":"Document - Patent",
"Document - ROW Permit":"Document - ROW Permit",
"Document - Survey Plat, Recorded":"Document - Survey Plat, Recorded",
"Document - Survey Plat, Unrecorded":"Document - Survey Plat, Unrecorded",
"Document - Other":"Document - Other",
"Digital - Aerial Photo":"Digital - Aerial Photo",
"Digital - BLM PLSS Data":"Digital - BLM PLSS Data",
"Digital - County Parcel Data":"Digital - County Parcel Data",
"Digital - Georeferenced Map or Plat":"Digital - Georeferenced Map or Plat",
"Digital - Survey Data":"Digital - Survey Data",
"Digital - Texas GLO Data":"Digital - Texas GLO Data",
"Digital - Other":"Digital - Other",
"Not Identified":"Not Identified"
}
arcpy.CreateDomain_management(thisDB, domainName, domainDescription, "TEXT", "CODED")
for code in  domainValues:
    arcpy.AddCodedValueToDomain_management(thisDB, domainName, code, domainValues[code])

# DOM_MONUTILITY_NPS2021 domain
# Domain name
domainName = "DOM_MONUTILITY_NPS2021"

# Domain description
domainDescription = "Primary utility/purpose of the survey monument"

# Domain values
domainValues = {
"Unknown":"Unknown",
"Boundary, accessory":"Boundary, accessory",
"Boundary, easement/ROW":"Boundary, easement/ROW",
"Boundary, historic":"Boundary, historic",
"Boundary, legislated":"Boundary, legislated",
"Boundary, private inholding":"Boundary, private inholding",
"Commemorative":"Commemorative",
"Boundary control":"Boundary control",
"Construction control":"Construction control",
"Elevation control":"Elevation control",
"Photogrammetric control":"Photogrammetric control",
"Resource monitoring":"Resource monitoring",
"Other":"Other"
}
arcpy.CreateDomain_management(thisDB, domainName, domainDescription, "TEXT", "CODED")
for code in  domainValues:
    arcpy.AddCodedValueToDomain_management(thisDB, domainName, code, domainValues[code])

# DOM_PUBLICDISPLAY_NPS2016 domain
# Domain name
domainName = "DOM_PUBLICDISPLAY_NPS2016"

# Domain description
domainDescription = "Determines if feature will be visible to the public or internal only"

# Domain values
domainValues = {
"No Public Map Display":"No Public Map Display",
"Public Map Display":"Public Map Display"
}
arcpy.CreateDomain_management(thisDB, domainName, domainDescription, "TEXT", "CODED")
for code in  domainValues:
    arcpy.AddCodedValueToDomain_management(thisDB, domainName, code, domainValues[code])

# DOM_XYACCURACY_NPS2016 domain
# Domain name
domainName = "DOM_XYACCURACY_NPS2016"

# Domain description
domainDescription = "Estimated accuracy based on source data"

# Domain values
domainValues = {
"<5cm":"<5cm",
">=5cm and <50cm":">=5cm and <50cm",
">=50cm and <1m":">=50cm and <1m",
">=1m and <5m":">=1m and <5m",
">=5m and <14m":">=5m and <14m",
">=14m":">=14m",
"Scaled":"Scaled",
"Unknown":"Unknown"
}
arcpy.CreateDomain_management(thisDB, domainName, domainDescription, "TEXT", "CODED")
for code in  domainValues:
    arcpy.AddCodedValueToDomain_management(thisDB, domainName, code, domainValues[code])

# DOM_YES_NO_LANDS2022 domain
# Domain name
domainName = "DOM_YES_NO_LANDS2022"

# Domain description
domainDescription = "Yes, no, both or unknown"

# Domain values
domainValues = {
"Yes":"Yes",
"No":"No",
"Both":"Both",
"Uknown":"Unknown"
}
arcpy.CreateDomain_management(thisDB, domainName, domainDescription, "TEXT", "CODED")
for code in  domainValues:
    arcpy.AddCodedValueToDomain_management(thisDB, domainName, code, domainValues[code])
    
# Report elapsed time
for i in range(100000):
    i*i
elapsed_time = time.time() - start_time
minutes = elapsed_time // 60
seconds = elapsed_time % 60
print(f"This code block took {int(minutes)} minutes and {seconds:.2f} seconds to run")
# Out:
# This code block took 1 minutes and 44.52 seconds to run

# %% [markdown]
# # Create Feature Dataset

# %%
# Create feature dataset  
arcpy.management.CreateFeatureDataset(thisDB, fdName, srs)

# Create topology and topology variables
topology =  "_" + fdName + "_Topology"
in_topology = FD +"/" +topology
arcpy.management.CreateTopology(FD,topology , "")
# Out:
# <Result 'E:\\Parks\\apro_projects\\TestTemplate\\ArcPro\\GOGA_Template.gdb\\GOGA_Features\\_GOGA_Features_Topology'>

# %% [markdown]
# # Create Point Feature Class
#    - Annotation_pt
#    - Notes_pt
#    - UseLocations_pt
#    - SurveyMon_pt

# %%
# Create point feature classes and add fields
#=============================================================================================#
start_time = time.time()
arcpy.Compact_management(thisDB) # often get schema lock here - this line seems to fix

featureClasses = [Annotation_pt]
for feature in featureClasses:
    fc = feature
    arcpy.management.CreateFeatureclass(FD, fc, "POINT", "", "", "", srs)
    arcpy.management.AddField(fc,"ANNOTYPE","TEXT","","",50,"ANNOTYPE","NULLABLE","NON_REQUIRED","DOM_ANNOTYPE_LANDS2022")
    time.sleep(1) # sometimes get schema lock here - pause seems to fix
    arcpy.management.AddField(fc,"FEATUREID","TEXT","","",50,"FEATUREID","NULLABLE","NON_REQUIRED","")
    arcpy.management.AddField(fc,"UNITCODE","TEXT","","",10,"UNITCODE","NULLABLE","NON_REQUIRED","")
    arcpy.management.AddField(fc,"NOTES","TEXT","","",254,"NOTES","NULLABLE","NON_REQUIRED","")
    arcpy.management.AddField(fc,"NOTES1","TEXT","","",254,"NOTES1","NULLABLE","NON_REQUIRED","")
    arcpy.management.AddField(fc,"DATAACCESS","TEXT","","",50,"DATAACCESS","NULLABLE","NON_REQUIRED","DOM_DATAACCESS_NPS2016")
    arcpy.management.AddField(fc,"PUBLICDISPLAY","TEXT","","",50,"PUBLICDISPLAY","NULLABLE","NON_REQUIRED","DOM_PUBLICDISPLAY_NPS2016")
    arcpy.management.AddField(fc,"EDITDATE","DATE","","","","EDITDATE","NULLABLE","NON_REQUIRED","")
    arcpy.management.AddField(fc,"EDITUSER","TEXT","","",50,"EDITUSER","NULLABLE","NON_REQUIRED","")
    arcpy.management.AddField(fc,"CREATEDATE","DATE","","","","CREATEDATE","NULLABLE","NON_REQUIRED","")
    arcpy.management.AddField(fc,"CREATEUSER","TEXT","","",50,"CREATEUSER","NULLABLE","NON_REQUIRED","")
    arcpy.management.AddField(fc,"LAYER","TEXT","","",254,"LAYER","NULLABLE","NON_REQUIRED","")
    arcpy.management.AddField(fc,"SOURCEFILE","TEXT","","",254,"SOURCEFILE","NULLABLE","NON_REQUIRED","")
    arcpy.management.AddField(fc,"MAPLABEL","TEXT","","",100,"MAPLABEL","NULLABLE","NON_REQUIRED","")
    
    
    # Create a new Metadata object and add some content to it
    new_md = md.Metadata()
    new_md.title = fc
    new_md.tags = "annotation, label"
    new_md.summary = "Used for storing annotation information, generally imported from AutoCAD files."
    new_md.description = "Serves as a feature class for storting custom annotation that will be available for map viewing."
    new_md.credits = unitCode +  ", NPS, Land Resources Division"
    new_md.accessConstraints = "There are no access and use limitations for this item."
    
    # Assign the Metadata object's content to a target item
    tgt_item_md = md.Metadata(fc)
    if not tgt_item_md.isReadOnly:
        tgt_item_md.copy(new_md)
        tgt_item_md.save()

#=============================================================================================#

featureClasses = [Notes_pt]
for feature in featureClasses:
    fc = feature
    arcpy.management.CreateFeatureclass(FD, fc, "POINT", "", "", "", srs)
    arcpy.management.AddField(fc,"FEATUREID","TEXT","","",50,"FEATUREID","NULLABLE","NON_REQUIRED","")
    arcpy.management.AddField(fc,"UNITCODE","TEXT","","",10,"UNITCODE","NULLABLE","NON_REQUIRED","")
    arcpy.management.AddField(fc,"NOTES","TEXT","","",254,"NOTES","NULLABLE","NON_REQUIRED","")
    arcpy.management.AddField(fc,"NOTES1","TEXT","","",254,"NOTES1","NULLABLE","NON_REQUIRED","")
    arcpy.management.AddField(fc,"DATAACCESS","TEXT","","",50,"DATAACCESS","NULLABLE","NON_REQUIRED","DOM_DATAACCESS_NPS2016")
    arcpy.management.AddField(fc,"PUBLICDISPLAY","TEXT","","",50,"PUBLICDISPLAY","NULLABLE","NON_REQUIRED","DOM_PUBLICDISPLAY_NPS2016")
    arcpy.management.AddField(fc,"EDITDATE","DATE","","","","EDITDATE","NULLABLE","NON_REQUIRED","")
    arcpy.management.AddField(fc,"EDITUSER","TEXT","","",50,"EDITUSER","NULLABLE","NON_REQUIRED","")
    arcpy.management.AddField(fc,"CREATEDATE","DATE","","","","CREATEDATE","NULLABLE","NON_REQUIRED","")
    arcpy.management.AddField(fc,"CREATEUSER","TEXT","","",50,"CREATEUSER","NULLABLE","NON_REQUIRED","")
    arcpy.management.AddField(fc,"LAYER","TEXT","","",254,"LAYER","NULLABLE","NON_REQUIRED","")
    arcpy.management.AddField(fc,"SOURCEFILE","TEXT","","",254,"SOURCEFILE","NULLABLE","NON_REQUIRED","")
    arcpy.management.AddField(fc,"MAPLABEL","TEXT","","",100,"MAPLABEL","NULLABLE","NON_REQUIRED","")
    
    
    # Create a new Metadata object and add some content to it
    new_md = md.Metadata()
    new_md.title = fc
    new_md.tags = "notes"
    new_md.summary = "Used for storing notes related to specific features (notes about source data, special circumstances with data input, accuracy, etc."
    new_md.description = "Serves as a feature class for preserving information about data creation process or other instructions helpful for future cartographers."
    new_md.credits = unitCode +  ", NPS, Land Resources Division"
    new_md.accessConstraints = "There are no access and use limitations for this item."
    
    # Assign the Metadata object's content to a target item
    tgt_item_md = md.Metadata(fc)
    if not tgt_item_md.isReadOnly:
        tgt_item_md.copy(new_md)
        tgt_item_md.save()

#=============================================================================================#

featureClasses = [UseLocations_pt]
for feature in featureClasses:
    fc = feature
    arcpy.management.CreateFeatureclass(FD, fc, "POINT", "", "", "", srs)
    arcpy.management.AddField(fc,"REC_STATE","TEXT","","",2,"REC_STATE","NULLABLE","NON_REQUIRED","")
    arcpy.management.AddField(fc,"REC_CNTY","TEXT","","",50,"REC_CNTY","NULLABLE","NON_REQUIRED","")
    arcpy.management.AddField(fc,"BK_VOL","TEXT","","",20,"BK_VOL","NULLABLE","NON_REQUIRED","")
    arcpy.management.AddField(fc,"PAGE","TEXT","","",20,"PAGE","NULLABLE","NON_REQUIRED","")
    arcpy.management.AddField(fc,"RECEPT_NO","TEXT","","",50,"RECEPT_NO","NULLABLE","NON_REQUIRED","")
    arcpy.management.AddField(fc,"REC_DATE","DATE","","","","REC_DATE","NULLABLE","NON_REQUIRED","")
    arcpy.management.AddField(fc,"INS_DATE","DATE","","","","INS_DATE","NULLABLE","NON_REQUIRED","")
    arcpy.management.AddField(fc,"GRANTOR","TEXT","","",100,"GRANTOR","NULLABLE","NON_REQUIRED","")
    arcpy.management.AddField(fc,"GRANTEE","TEXT","","",100,"GRANTEE","NULLABLE","NON_REQUIRED","")
    arcpy.management.AddField(fc,"SURV_DATE","DATE","","","","SURV_DATE","NULLABLE","NON_REQUIRED","")
    arcpy.management.AddField(fc,"PLAT_TITLE","TEXT","","",254,"PLAT_TITLE","NULLABLE","NON_REQUIRED","")
    arcpy.management.AddField(fc,"BNDY_TYPE","TEXT","","",50,"BNDY_TYPE","NULLABLE","NON_REQUIRED","DOM_BNDYTYPE_LANDS2022")
    arcpy.management.AddField(fc,"GEN_USE_TYPE","TEXT","","",24,"GEN_USE_TYPE","NULLABLE","NON_REQUIRED","DOM_USETYPE_LANDS2022")
    arcpy.management.AddField(fc,"PERMIT_NO","TEXT","","",20,"PERMIT_NO","NULLABLE","NON_REQUIRED","")
    arcpy.management.AddField(fc,"EXP_DATE","DATE","","","","EXP_DATE","NULLABLE","NON_REQUIRED","")
    arcpy.management.AddField(fc,"ACTIVE","TEXT","","",20,"ACTIVE","NULLABLE","NON_REQUIRED","DOM_YES_NO_LANDS2022")
    
    # Create a new Metadata object and add some content to it
    new_md = md.Metadata()
    new_md.title = fc
    new_md.tags = "easement, encumbrance, utility"
    new_md.summary = "Point feature class for all easements, encumbrances and uses identified in title commitments or on survey plats."
    new_md.description = "Serves as a staging area and document tracking (i.e. source land records) used for title commitment review and other research for easement, encumberances and use interests. Fee simple interests or land survey plat information should be input in the SurveyMon_pt feature class. Data is developed from descriptions of record or imported from other data sources."
    new_md.credits = unitCode +  ", NPS, Land Resources Division"
    new_md.accessConstraints = "There are no access and use limitations for this item."
    
    # Assign the Metadata object's content to a target item
    tgt_item_md = md.Metadata(fc)
    if not tgt_item_md.isReadOnly:
        tgt_item_md.copy(new_md)
        tgt_item_md.save()

#=============================================================================================#

featureClasses = [SurveyMon_pt]
for feature in featureClasses:
    fc = feature
    arcpy.management.CreateFeatureclass(FD, fc, "POINT", "", "", "", srs)
    arcpy.management.AddField(fc,"ISOUTPARK","TEXT","","",10,"ISOUTPARK","NULLABLE","NON_REQUIRED","DOM_YES_NO_LANDS2022")
    arcpy.management.AddField(fc,"MONDESC","TEXT","","",254,"MONDESC","NULLABLE","NON_REQUIRED","")
    arcpy.management.AddField(fc,"MONIMGLINK","TEXT","","",254,"MONIMGLINK","NULLABLE","NON_REQUIRED","")
    arcpy.management.AddField(fc,"MONRECOVBY","TEXT","","",50,"MONRECOVBY","NULLABLE","NON_REQUIRED","")
    arcpy.management.AddField(fc,"MONRECOVDATE","DATE","","","","MONRECOVDATE","NULLABLE","NON_REQUIRED","")
    arcpy.management.AddField(fc,"MONSETBY","TEXT","","",50,"MONSETBY","NULLABLE","NON_REQUIRED","")
    arcpy.management.AddField(fc,"MONSETDATE","DATE","","","","MONSETDATE","NULLABLE","NON_REQUIRED","")
    arcpy.management.AddField(fc,"MONSTAMPID","TEXT","","",254,"MONSTAMPID","NULLABLE","NON_REQUIRED","")
    arcpy.management.AddField(fc,"MONUTILITY","TEXT","","",50,"MONUTILITY","NULLABLE","NON_REQUIRED","DOM_MONUTILITY_NPS2021")
    
    # Create a new Metadata object and add some content to it
    new_md = md.Metadata()
    new_md.title = fc
    new_md.tags = "survey, monuments, survey monuments, corners, corner points, boundary survey, boundary point"
    new_md.summary = "Depicts survey monument point data and information."
    new_md.description = "Serves as a repository for any/all survey monumentation related to tract and boundary angle points or other project control points. Sources include GPS field data, total station field data, data derived from survey plats and other land description information (calls for monuments, etc.) The attributes are based on the current national data standard for the NPS Monumentation Database. Features can be easily exported to the national dataset if needed."
    new_md.credits = unitCode +  ", NPS, Land Resources Division"
    new_md.accessConstraints = "There are no access and use limitations for this item."
    
    # Assign the Metadata object's content to a target item
    tgt_item_md = md.Metadata(fc)
    if not tgt_item_md.isReadOnly:
        tgt_item_md.copy(new_md)
        tgt_item_md.save()

# Report elapsed time
for i in range(100000):
    i*i
elapsed_time = time.time() - start_time
minutes = elapsed_time // 60
seconds = elapsed_time % 60
print(f"This code block took {int(minutes)} minutes and {seconds:.2f} seconds to run")
# Out:
# This code block took 1 minutes and 52.81 seconds to run

# %% [markdown]
# # Create Line Feature Class
#    - Annotation_ln
#    - LegisHist_ln
#    - UseLocations_ln
#    - SurveyBndy_ln
#    - TractsBndy_ln

# %%
# Create line feature classes and add fields
#=============================================================================================#
start_time = time.time()
arcpy.Compact_management(thisDB) # often get schema lock here - this line seems to fix

featureClasses = [Annotation_ln]
for feature in featureClasses:
    fc = feature
    arcpy.management.CreateFeatureclass(FD, fc, "POLYLINE", "", "", "", srs)
    arcpy.management.AddField(fc,"ANNOTYPE","TEXT","","",50,"ANNOTYPE","NULLABLE","NON_REQUIRED","DOM_ANNOTYPE_LANDS2022")
    arcpy.management.AddField(fc,"FEATUREID","TEXT","","",50,"FEATUREID","NULLABLE","NON_REQUIRED","")
    arcpy.management.AddField(fc,"UNITCODE","TEXT","","",10,"UNITCODE","NULLABLE","NON_REQUIRED","")
    arcpy.management.AddField(fc,"NOTES","TEXT","","",254,"NOTES","NULLABLE","NON_REQUIRED","")
    time.sleep(1) # sometimes get schema lock here - pause seems to fix
    arcpy.management.AddField(fc,"NOTES1","TEXT","","",254,"NOTES1","NULLABLE","NON_REQUIRED","")
    arcpy.management.AddField(fc,"DATAACCESS","TEXT","","",50,"DATAACCESS","NULLABLE","NON_REQUIRED","DOM_DATAACCESS_NPS2016")
    arcpy.management.AddField(fc,"PUBLICDISPLAY","TEXT","","",50,"PUBLICDISPLAY","NULLABLE","NON_REQUIRED","DOM_PUBLICDISPLAY_NPS2016")
    arcpy.management.AddField(fc,"EDITDATE","DATE","","","","EDITDATE","NULLABLE","NON_REQUIRED","")
    arcpy.management.AddField(fc,"EDITUSER","TEXT","","",50,"EDITUSER","NULLABLE","NON_REQUIRED","")
    arcpy.management.AddField(fc,"CREATEDATE","DATE","","","","CREATEDATE","NULLABLE","NON_REQUIRED","")
    arcpy.management.AddField(fc,"CREATEUSER","TEXT","","",50,"CREATEUSER","NULLABLE","NON_REQUIRED","")
    arcpy.management.AddField(fc,"LAYER","TEXT","","",254,"LAYER","NULLABLE","NON_REQUIRED","")
    arcpy.management.AddField(fc,"SOURCEFILE","TEXT","","",254,"SOURCEFILE","NULLABLE","NON_REQUIRED","")
    arcpy.management.AddField(fc,"MAPLABEL","TEXT","","",100,"MAPLABEL","NULLABLE","NON_REQUIRED","")
     
    # Create a new Metadata object and add some content to it
    new_md = md.Metadata()
    new_md.title = fc
    new_md.tags = "annotation, label"
    new_md.summary = "Used for storing annotation information, generally imported from AutoCAD files."
    new_md.description = "Serves as a feature class for storting custom annotation that will be available for map viewing."
    new_md.credits = unitCode +  ", NPS, Land Resources Division"
    new_md.accessConstraints = "There are no access and use limitations for this item."
    
    # Assign the Metadata object's content to a target item
    tgt_item_md = md.Metadata(fc)
    if not tgt_item_md.isReadOnly:
        tgt_item_md.copy(new_md)
        tgt_item_md.save()

#=============================================================================================#

featureClasses = [LegisHist_ln]
for feature in featureClasses:
    fc = feature
    arcpy.management.CreateFeatureclass(FD, fc, "POLYLINE", "", "", "", srs)
    arcpy.management.AddField(fc,"STATE","TEXT","","",2,"STATE","NULLABLE","NON_REQUIRED","")
    arcpy.management.AddField(fc,"BNDY_DATE","DATE","","","","BNDY_DATE","NULLABLE","NON_REQUIRED","")
    arcpy.management.AddField(fc,"LEGIS","TEXT","","",50,"LEGIS","NULLABLE","NON_REQUIRED","")
    arcpy.management.AddField(fc,"LEG_YEAR","SHORT","","","","LEG_YEAR","NULLABLE","NON_REQUIRED","")
    arcpy.management.AddField(fc,"LEGIS2","TEXT","","",50,"LEGIS2","NULLABLE","NON_REQUIRED","")
    arcpy.management.AddField(fc,"LEG_YEAR2","SHORT","","","","LEG_YEAR2","NULLABLE","NON_REQUIRED","")
    
    # Create a new Metadata object and add some content to it
    new_md = md.Metadata()
    new_md.title = fc
    new_md.tags = "boundary, legislative boundary, historical legislation, old boundary"
    new_md.summary = "Historical authorized legislative boundaries of the park unit."
    new_md.description = "Serves as the final official NPS historical legislated boundary data for the park unit. Park units with multiple legislative actions (boundary revisions, changes to park designation, etc.) benefit from this information when determining acquisition authority for any given area of the park. This information is also useful for historical research. Line data in the feature class provides for easy updates to the corresponding polygon feature class LegisHist_py."
    new_md.credits = unitCode, "Land Resources Division"
    new_md.accessConstraints = "There are no access and use limitations for this item."

    # Assign the Metadata object's content to a target item
    tgt_item_md = md.Metadata(fc)
    if not tgt_item_md.isReadOnly:
        tgt_item_md.copy(new_md)
        tgt_item_md.save()

#=============================================================================================#

featureClasses = [UseLocations_ln]
for feature in featureClasses:
    fc = feature
    arcpy.management.CreateFeatureclass(FD, fc, "POLYLINE", "", "", "", srs)
    arcpy.management.AddField(fc,"REC_STATE","TEXT","","",2,"REC_STATE","NULLABLE","NON_REQUIRED","")
    arcpy.management.AddField(fc,"REC_CNTY","TEXT","","",50,"REC_CNTY","NULLABLE","NON_REQUIRED","")
    arcpy.management.AddField(fc,"BK_VOL","TEXT","","",20,"BK_VOL","NULLABLE","NON_REQUIRED","")
    arcpy.management.AddField(fc,"PAGE","TEXT","","",20,"PAGE","NULLABLE","NON_REQUIRED","")
    arcpy.management.AddField(fc,"RECEPT_NO","TEXT","","",50,"RECEPT_NO","NULLABLE","NON_REQUIRED","")
    arcpy.management.AddField(fc,"REC_DATE","DATE","","","","REC_DATE","NULLABLE","NON_REQUIRED","")
    arcpy.management.AddField(fc,"INS_DATE","DATE","","","","INS_DATE","NULLABLE","NON_REQUIRED","")
    arcpy.management.AddField(fc,"GRANTOR","TEXT","","",100,"GRANTOR","NULLABLE","NON_REQUIRED","")
    arcpy.management.AddField(fc,"GRANTEE","TEXT","","",100,"GRANTEE","NULLABLE","NON_REQUIRED","")
    arcpy.management.AddField(fc,"SURV_DATE","DATE","","","","SURV_DATE","NULLABLE","NON_REQUIRED","")
    arcpy.management.AddField(fc,"PLAT_TITLE","TEXT","","",254,"PLAT_TITLE","NULLABLE","NON_REQUIRED","")
    arcpy.management.AddField(fc,"BNDY_TYPE","TEXT","","",50,"BNDY_TYPE","NULLABLE","NON_REQUIRED","DOM_BNDYTYPE_LANDS2022")
    arcpy.management.AddField(fc,"GEN_USE_TYPE","TEXT","","",24,"GEN_USE_TYPE","NULLABLE","NON_REQUIRED","DOM_USETYPE_LANDS2022")
    arcpy.management.AddField(fc,"PERMIT_NO","TEXT","","",20,"PERMIT_NO","NULLABLE","NON_REQUIRED","")
    arcpy.management.AddField(fc,"EXP_DATE","DATE","","","","EXP_DATE","NULLABLE","NON_REQUIRED","")
    arcpy.management.AddField(fc,"ACTIVE","TEXT","","",20,"ACTIVE","NULLABLE","NON_REQUIRED","DOM_YES_NO_LANDS2022")
    
    # Create a new Metadata object and add some content to it
    new_md = md.Metadata()
    new_md.title = fc
    new_md.tags = "easement, encumbrance, utility"
    new_md.summary = "Line feature class for all easements, encumbrances and uses identified in title commitments or on survey plats."
    new_md.description = "Serves as a staging area and document tracking (i.e. source land records) used for title commitment review and other research for easement, encumberances and use interests. Fee simple interests or land survey plat information should be input in the SurveyBndy_ln feature class. Data is developed with COGO tools from descriptions of record or imported from other data sources. Corresponding polygons are then generated in UseLocations_py. "
    new_md.credits = unitCode +  ", NPS, Land Resources Division"
    new_md.accessConstraints = "There are no access and use limitations for this item."

    # Assign the Metadata object's content to a target item
    tgt_item_md = md.Metadata(fc)
    if not tgt_item_md.isReadOnly:
        tgt_item_md.copy(new_md)
        tgt_item_md.save()

#=============================================================================================#

featureClasses = [SurveyBndy_ln]
for feature in featureClasses:
    fc = feature
    arcpy.management.CreateFeatureclass(FD, fc, "POLYLINE", "", "", "", srs)
    arcpy.management.AddField(fc,"REC_STATE","TEXT","","",2,"REC_STATE","NULLABLE","NON_REQUIRED","")
    arcpy.management.AddField(fc,"REC_CNTY","TEXT","","",50,"REC_CNTY","NULLABLE","NON_REQUIRED","")
    arcpy.management.AddField(fc,"BK_VOL","TEXT","","",20,"BK_VOL","NULLABLE","NON_REQUIRED","")
    arcpy.management.AddField(fc,"PAGE","TEXT","","",20,"PAGE","NULLABLE","NON_REQUIRED","")
    arcpy.management.AddField(fc,"RECEPT_NO","TEXT","","",50,"RECEPT_NO","NULLABLE","NON_REQUIRED","")
    arcpy.management.AddField(fc,"REC_DATE","DATE","","","","REC_DATE","NULLABLE","NON_REQUIRED","")
    arcpy.management.AddField(fc,"INS_DATE","DATE","","","","INS_DATE","NULLABLE","NON_REQUIRED","")
    arcpy.management.AddField(fc,"GRANTOR","TEXT","","",100,"GRANTOR","NULLABLE","NON_REQUIRED","")
    arcpy.management.AddField(fc,"GRANTEE","TEXT","","",100,"GRANTEE","NULLABLE","NON_REQUIRED","")
    arcpy.management.AddField(fc,"SURV_DATE","DATE","","","","SURV_DATE","NULLABLE","NON_REQUIRED","")
    arcpy.management.AddField(fc,"PLAT_TITLE","TEXT","","",254,"PLAT_TITLE","NULLABLE","NON_REQUIRED","")
    arcpy.management.AddField(fc,"BNDY_TYPE","TEXT","","",50,"BNDY_TYPE","NULLABLE","NON_REQUIRED","DOM_BNDYTYPE_LANDS2022")
    
    # Create a new Metadata object and add some content to it
    new_md = md.Metadata()
    new_md.title = fc
    new_md.tags = "survey, plat, subdivision, COGO, lot boundary, deed line"
    new_md.summary = "Line feature class for  all land description line work related to deeded lot lines and survey plat boundary information."
    new_md.description = "Serves as a staging area and document tracking (i.e. source land records) used for title commitment review, land record research and in developing official tract and boundary data. This feature class is COGO-enabled and should be utilized for all land description line work related to deeded lot lines and survey plat boundary information. Easement, encumbrance and use information should be input in the UseLocations_ln feature class. Information in this feature class may be used as a basis for data in the SurfaceOwn_py, SubsurfOwn_py, Survey_py, and the tract and boundary feature classes."
    new_md.credits = unitCode +  ", NPS, Land Resources Division"
    new_md.accessConstraints = "There are no access and use limitations for this item."

    # Assign the Metadata object's content to a target item
    tgt_item_md = md.Metadata(fc)
    if not tgt_item_md.isReadOnly:
        tgt_item_md.copy(new_md)
        tgt_item_md.save()

#=============================================================================================#

featureClasses = [TractsBndy_ln]
for feature in featureClasses:
    fc = feature
    arcpy.management.CreateFeatureclass(FD, fc, "POLYLINE", "", "", "", srs)
    arcpy.management.AddField(fc,"BNDY_TYPE","TEXT","","",50,"BNDY_TYPE","NULLABLE","NON_REQUIRED","DOM_BNDYTYPE_LANDS2022")
    # Add feature class to topology
    arcpy.management.AddFeatureClassToTopology(in_topology, fc, 1, "")
    
    # Create a new Metadata object and add some content to it
    new_md = md.Metadata()
    new_md.title = fc
    new_md.tags = "tracts, tract boundary, boundary, boundary line"
    new_md.summary = "Used for compiling final line data depicting tract boundaries, legislated park boundaries, secondary tract boundaries, mineral boundaries, etc."
    new_md.description = "Serves as the final line feature class repository prior to creating tract and boundary polygon data. The linework in this layer is usually derived from the SurveyBndy_ln or EsmtBndy_ln layers, then adjusted (if needed), then cleaned up for topological errors (no gaps, overlaps, pseudo nodes, etc.)"
    new_md.credits = unitCode +  ", NPS, Land Resources Division"
    new_md.accessConstraints = "There are no access and use limitations for this item."

    # Assign the Metadata object's content to a target item
    tgt_item_md = md.Metadata(fc)
    if not tgt_item_md.isReadOnly:
        tgt_item_md.copy(new_md)
        tgt_item_md.save() 

# Report elapsed time
for i in range(100000):
    i*i
elapsed_time = time.time() - start_time
minutes = elapsed_time // 60
seconds = elapsed_time % 60
print(f"This code block took {int(minutes)} minutes and {seconds:.2f} seconds to run")
# Out:
# This code block took 4 minutes and 40.18 seconds to run

# %% [markdown]
# # Create Poly Feature Class
#    - Boundary_py
#    - LegisHist_py
#    - UseLocations_py
#    - SubsurfOwn_py
#    - SurfaceOwn_py
#    - Survey_py
#    - Tracts_py

# %%
# Create Poly feature classes and add fields
#=============================================================================================#
start_time = time.time()
arcpy.Compact_management(thisDB) # often get schema lock here - this line seems to fix

featureClasses = [Boundary_py]
for feature in featureClasses:
    fc = feature
    arcpy.management.CreateFeatureclass(FD, fc, "POLYGON", "", "", "", srs)
    arcpy.management.AddField(fc,"FEATUREID","TEXT","","",50,"AREAID","NULLABLE","NON_REQUIRED","")
    arcpy.management.AddField(fc,"BNDY_TYPE","TEXT","","",50,"BNDY_TYPE","NULLABLE","NON_REQUIRED","DOM_BNDYTYPE_LANDS2022")

    
    # Add feature class to topology
    arcpy.management.AddFeatureClassToTopology(in_topology, fc, 3, "")
    
    # Create a new Metadata object and add some content to it
    new_md = md.Metadata()
    new_md.title = fc
    new_md.tags = "NPS boundary, boundary, park boundary"
    new_md.summary = "Current authorized legislated boundary of the park unit."
    new_md.description = "Serves as the final official NPS legislated boundary data for the park unit. The polygons are derived from the line data stored in TractsBndy_ln. Data for this feature class is generally developed in SurveyBndy_ln before being copied to the TractsBndy_ln feature class for final data adjustments."
    new_md.credits = unitCode +  ", NPS, Land Resources Division"
    new_md.accessConstraints = "There are no access and use limitations for this item."

    # Assign the Metadata object's content to a target item
    tgt_item_md = md.Metadata(fc)
    if not tgt_item_md.isReadOnly:
        tgt_item_md.copy(new_md)
        tgt_item_md.save()

#=============================================================================================#

featureClasses = [LegisHist_py]
for feature in featureClasses:
    fc = feature
    arcpy.management.CreateFeatureclass(FD, fc, "POLYGON", "", "", "", srs)
    arcpy.management.AddField(fc,"STATE","TEXT","","",2,"STATE","NULLABLE","NON_REQUIRED","")
    arcpy.management.AddField(fc,"BNDY_DATE","DATE","","","","BNDY_DATE","NULLABLE","NON_REQUIRED","")
    arcpy.management.AddField(fc,"LEGIS","TEXT","","",50,"LEGIS","NULLABLE","NON_REQUIRED","")
    arcpy.management.AddField(fc,"LEG_YEAR","SHORT","","","","LEG_YEAR","NULLABLE","NON_REQUIRED","")
    arcpy.management.AddField(fc,"LEGIS2","TEXT","","",50,"LEGIS2","NULLABLE","NON_REQUIRED","")
    arcpy.management.AddField(fc,"LEG_YEAR2","SHORT","","","","LEG_YEAR2","NULLABLE","NON_REQUIRED","")
    
    # Create a new Metadata object and add some content to it
    new_md = md.Metadata()
    new_md.title = fc
    new_md.tags = "boundary, legislative boundary, historical legislation, old boundary"
    new_md.summary = "Historical authorized legislative boundaries of the park unit."
    new_md.description = "Serves as the final official NPS historical legislated boundary data for the park unit. Park units with multiple legislative actions (boundary revisions, changes to park designation, etc.) benefit from this information when determining acquisition authority for any given area of the park. This information is also useful for historical research. Line data in the LegisHist_ln feature class provides for easier updates to this feature class."
    new_md.credits = unitCode +  ", NPS, Land Resources Division"
    new_md.accessConstraints = "There are no access and use limitations for this item."

    # Assign the Metadata object's content to a target item
    tgt_item_md = md.Metadata(fc)
    if not tgt_item_md.isReadOnly:
        tgt_item_md.copy(new_md)
        tgt_item_md.save()

#=============================================================================================#

featureClasses = [UseLocations_py]
for feature in featureClasses:
    fc = feature
    arcpy.management.CreateFeatureclass(FD, fc, "POLYGON", "", "", "", srs)
    arcpy.management.AddField(fc,"USE_BNDY_NO","TEXT","","",20,"USE_BNDY_NO","NULLABLE","NON_REQUIRED","")
    arcpy.management.AddField(fc,"REC_STATE","TEXT","","",2,"REC_STATE","NULLABLE","NON_REQUIRED","")
    arcpy.management.AddField(fc,"REC_CNTY","TEXT","","",50,"REC_CNTY","NULLABLE","NON_REQUIRED","")
    arcpy.management.AddField(fc,"BK_VOL","TEXT","","",20,"BK_VOL","NULLABLE","NON_REQUIRED","")
    arcpy.management.AddField(fc,"PAGE","TEXT","","",20,"PAGE","NULLABLE","NON_REQUIRED","")
    arcpy.management.AddField(fc,"RECEPT_NO","TEXT","","",50,"RECEPT_NO","NULLABLE","NON_REQUIRED","")
    arcpy.management.AddField(fc,"REC_DATE","DATE","","","","REC_DATE","NULLABLE","NON_REQUIRED","")
    arcpy.management.AddField(fc,"INS_DATE","DATE","","","","INS_DATE","NULLABLE","NON_REQUIRED","")
    arcpy.management.AddField(fc,"GRANTOR","TEXT","","",100,"GRANTOR","NULLABLE","NON_REQUIRED","")
    arcpy.management.AddField(fc,"GRANTEE","TEXT","","",100,"GRANTEE","NULLABLE","NON_REQUIRED","")
    arcpy.management.AddField(fc,"SURV_DATE","DATE","","","","SURV_DATE","NULLABLE","NON_REQUIRED","")
    arcpy.management.AddField(fc,"PLAT_TITLE","TEXT","","",254,"PLAT_TITLE","NULLABLE","NON_REQUIRED","")
    arcpy.management.AddField(fc,"BNDY_TYPE","TEXT","","",50,"BNDY_TYPE","NULLABLE","NON_REQUIRED","DOM_BNDYTYPE_LANDS2022")
    arcpy.management.AddField(fc,"GEN_USE_TYPE","TEXT","","",24,"GEN_USE_TYPE","NULLABLE","NON_REQUIRED","DOM_USETYPE_LANDS2022")
    arcpy.management.AddField(fc,"PERMIT_NO","TEXT","","",20,"PERMIT_NO","NULLABLE","NON_REQUIRED","")
    arcpy.management.AddField(fc,"EXP_DATE","DATE","","","","EXP_DATE","NULLABLE","NON_REQUIRED","")
    arcpy.management.AddField(fc,"ACTIVE","TEXT","","",20,"ACTIVE","NULLABLE","NON_REQUIRED","DOM_YES_NO_LANDS2022")
    arcpy.management.AddField(fc,"LEGAL_ACRE","DOUBLE","","","","LEGAL_ACRE","NULLABLE","NON_REQUIRED","")
    arcpy.management.AddField(fc,"GIS_ACRE","DOUBLE","","","","GIS_ACRE","NULLABLE","NON_REQUIRED","")
    arcpy.management.AddField(fc,"FEATUREID","TEXT","","",50,"LOCATIONKEY","NULLABLE","NON_REQUIRED","")
    
    # Create a new Metadata object and add some content to it
    new_md = md.Metadata()
    new_md.title = fc
    new_md.tags = "easement, encumbrance, utility"
    new_md.summary = "Stores polygon information corresponding to NPS-issued instruments documented in the MLC Use Manager. "
    new_md.description = "NPS-issued use areas developed from data provided by applicant (geospatial data, land descriptions or survey plats). Linework can be developed in the COGO_UseLocations_ln feature class."
    new_md.credits = unitCode +  ", NPS, Land Resources Division"
    new_md.accessConstraints = "There are no access and use limitations for this item."

    # Assign the Metadata object's content to a target item
    tgt_item_md = md.Metadata(fc)
    if not tgt_item_md.isReadOnly:
        tgt_item_md.copy(new_md)
        tgt_item_md.save()

#=============================================================================================#

featureClasses = [SubsurfOwn_py]
for feature in featureClasses:
    fc = feature
    arcpy.management.CreateFeatureclass(FD, fc, "POLYGON", "", "", "", srs)
    arcpy.management.AddField(fc,"REC_STATE","TEXT","","",2,"REC_STATE","NULLABLE","NON_REQUIRED","")
    arcpy.management.AddField(fc,"REC_CNTY","TEXT","","",50,"REC_CNTY","NULLABLE","NON_REQUIRED","")
    arcpy.management.AddField(fc,"BK_VOL","TEXT","","",20,"BK_VOL","NULLABLE","NON_REQUIRED","")
    arcpy.management.AddField(fc,"PAGE","TEXT","","",20,"PAGE","NULLABLE","NON_REQUIRED","")
    arcpy.management.AddField(fc,"RECEPT_NO","TEXT","","",50,"RECEPT_NO","NULLABLE","NON_REQUIRED","")
    arcpy.management.AddField(fc,"REC_DATE","DATE","","","","REC_DATE","NULLABLE","NON_REQUIRED","")
    arcpy.management.AddField(fc,"INS_DATE","DATE","","","","INS_DATE","NULLABLE","NON_REQUIRED","")
    arcpy.management.AddField(fc,"GRANTOR","TEXT","","",100,"GRANTOR","NULLABLE","NON_REQUIRED","")
    arcpy.management.AddField(fc,"GRANTEE","TEXT","","",100,"GRANTEE","NULLABLE","NON_REQUIRED","")
    arcpy.management.AddField(fc,"LEGAL_ACRE","DOUBLE","","","","LEGAL_ACRE","NULLABLE","NON_REQUIRED","")
    arcpy.management.AddField(fc,"GIS_ACRE","DOUBLE","","","","GIS_ACRE","NULLABLE","NON_REQUIRED","")

    # Create a new Metadata object and add some content to it
    new_md = md.Metadata()
    new_md.title = fc
    new_md.tags = "mineral rights, mineral owner, mineral, subsurface"
    new_md.summary = "Depicts subsurface owner rights or interests which differ from the surface owner (severed estate)."
    new_md.description = "Serves as a staging area and document tracking (i.e. source land records) used for title commitment review and other research related to subsurface rights which are owned separately from the surface owner (known as severed rights). Utilize the SurveyBndy_ln feature class for any COGO line work prior to creating polygon data in this feature class."
    new_md.credits = unitCode +  ", NPS, Land Resources Division"
    new_md.accessConstraints = "There are no access and use limitations for this item."

    # Assign the Metadata object's content to a target item
    tgt_item_md = md.Metadata(fc)
    if not tgt_item_md.isReadOnly:
        tgt_item_md.copy(new_md)
        tgt_item_md.save()

#=============================================================================================#

featureClasses = [SurfaceOwn_py]
for feature in featureClasses:
    fc = feature
    arcpy.management.CreateFeatureclass(FD, fc, "POLYGON", "", "", "", srs)
    arcpy.management.AddField(fc,"REC_STATE","TEXT","","",2,"REC_STATE","NULLABLE","NON_REQUIRED","")
    arcpy.management.AddField(fc,"REC_CNTY","TEXT","","",50,"REC_CNTY","NULLABLE","NON_REQUIRED","")
    arcpy.management.AddField(fc,"BK_VOL","TEXT","","",20,"BK_VOL","NULLABLE","NON_REQUIRED","")
    arcpy.management.AddField(fc,"PAGE","TEXT","","",20,"PAGE","NULLABLE","NON_REQUIRED","")
    arcpy.management.AddField(fc,"RECEPT_NO","TEXT","","",50,"RECEPT_NO","NULLABLE","NON_REQUIRED","")
    arcpy.management.AddField(fc,"REC_DATE","DATE","","","","REC_DATE","NULLABLE","NON_REQUIRED","")
    arcpy.management.AddField(fc,"INS_DATE","DATE","","","","INS_DATE","NULLABLE","NON_REQUIRED","")
    arcpy.management.AddField(fc,"GRANTOR","TEXT","","",100,"GRANTOR","NULLABLE","NON_REQUIRED","")
    arcpy.management.AddField(fc,"GRANTEE","TEXT","","",100,"GRANTEE","NULLABLE","NON_REQUIRED","")
    arcpy.management.AddField(fc,"LEGAL_ACRE","DOUBLE","","","","LEGAL_ACRE","NULLABLE","NON_REQUIRED","")
    arcpy.management.AddField(fc,"GIS_ACRE","DOUBLE","","","","GIS_ACRE","NULLABLE","NON_REQUIRED","")
    
    # Create a new Metadata object and add some content to it
    new_md = md.Metadata()
    new_md.title = fc
    new_md.tags = "landowner, surface owner, ownership"
    new_md.summary = "Depicts surface owner fee simple title information for tracking chain of title ownership."
    new_md.description = "Serves as a staging area and document tracking (i.e. source land records) used for title commitment review and other research related to the surface (fee simple) owners of record. Utilize the SurveyBndy_ln feature class for any COGO line work prior to creating polygon data in this feature class."
    new_md.credits = unitCode +  ", NPS, Land Resources Division"
    new_md.accessConstraints = "There are no access and use limitations for this item."

    # Assign the Metadata object's content to a target item
    tgt_item_md = md.Metadata(fc)
    if not tgt_item_md.isReadOnly:
        tgt_item_md.copy(new_md)
        tgt_item_md.save()

#=============================================================================================#

featureClasses = [Survey_py]
for feature in featureClasses:
    fc = feature
    arcpy.management.CreateFeatureclass(FD, fc, "POLYGON", "", "", "", srs)
    arcpy.management.AddField(fc,"REC_STATE","TEXT","","",2,"REC_STATE","NULLABLE","NON_REQUIRED","")
    arcpy.management.AddField(fc,"REC_CNTY","TEXT","","",50,"REC_CNTY","NULLABLE","NON_REQUIRED","")
    arcpy.management.AddField(fc,"BK_VOL","TEXT","","",20,"BK_VOL","NULLABLE","NON_REQUIRED","")
    arcpy.management.AddField(fc,"PAGE","TEXT","","",20,"PAGE","NULLABLE","NON_REQUIRED","")
    arcpy.management.AddField(fc,"RECEPT_NO","TEXT","","",50,"RECEPT_NO","NULLABLE","NON_REQUIRED","")
    arcpy.management.AddField(fc,"REC_DATE","DATE","","","","REC_DATE","NULLABLE","NON_REQUIRED","")
    arcpy.management.AddField(fc,"INS_DATE","DATE","","","","INS_DATE","NULLABLE","NON_REQUIRED","")
    arcpy.management.AddField(fc,"SURV_DATE","DATE","","","","SURV_DATE","NULLABLE","NON_REQUIRED","")
    arcpy.management.AddField(fc,"PLAT_TITLE","TEXT","","",254,"PLAT_TITLE","NULLABLE","NON_REQUIRED","")
    arcpy.management.AddField(fc,"LEGAL_ACRE","DOUBLE","","","","LEGAL_ACRE","NULLABLE","NON_REQUIRED","")
    arcpy.management.AddField(fc,"GIS_ACRE","DOUBLE","","","","GIS_ACRE","NULLABLE","NON_REQUIRED","")

    # Create a new Metadata object and add some content to it
    new_md = md.Metadata()
    new_md.title = fc
    new_md.tags = "land survey, survey plat, plat, subdivision, subdivision plat, certificate of survey, survey"
    new_md.summary = "Depicts the extents of surveyed parcels, including subdivision plats, land survey plats, certificates of survey, etc."
    new_md.description = "Serves as a staging area and document tracking (i.e. source land records) used for title commitment review, land record research and in developing official tract and boundary data. Subdivision and land survey plats define boundaries but do not track ownership interests. Information in this feature class may be used as a basis for data in the SurfaceOwn_py, SubsurfOwn_py and the tract and boundary feature classes. Parks in urban areas are likely covered by one or more areas with official subdivision or land survey plat information. Utilize the LANDS_SurveyBndy_ln feature class for any COGO line work prior to creating polygon data in this feature class."
    new_md.credits = unitCode +  ", NPS, Land Resources Division"
    new_md.accessConstraints = "There are no access and use limitations for this item."

    # Assign the Metadata object's content to a target item
    tgt_item_md = md.Metadata(fc)
    if not tgt_item_md.isReadOnly:
        tgt_item_md.copy(new_md)
        tgt_item_md.save()

#=============================================================================================#

featureClasses = [Tracts_py]
for feature in featureClasses:
    fc = feature
    arcpy.management.CreateFeatureclass(FD, fc, "POLYGON", "", "", "", srs)
    arcpy.management.AddField(fc,"TRACT_ID","TEXT","","",20,"TRACTNUMBER","NULLABLE","NON_REQUIRED","")
    arcpy.management.AddField(fc,"FEATUREID","TEXT","","",50,"ALPHATRACT","NULLABLE","NON_REQUIRED","")
    arcpy.management.AddField(fc,"BNDY_TYPE","TEXT","","",50,"BNDY_TYPE","NULLABLE","NON_REQUIRED","DOM_BNDYTYPE_LANDS2022")
    
    # Add feature class to topology
    arcpy.management.AddFeatureClassToTopology(in_topology, fc, 2, "")
    
    # Create a new Metadata object and add some content to it
    new_md = md.Metadata()
    new_md.title = fc
    new_md.tags = "tracts, NPS tracts, land status, NPS land ownership, ownership, acquisition"
    new_md.summary = "Current NPS interest at the tract-level."
    new_md.description = "Serves as the final official NPS tract-level data for the park unit. The polygons are derived from the clean line data stored in the TractsBndy_ln layer. Data for this feature class is generally developed in SurveyBndy_ln before being copied to the "
    new_md.credits = unitCode +  ", NPS, Land Resources Division"
    new_md.accessConstraints = "There are no access and use limitations for this item."

    # Assign the Metadata object's content to a target item
    tgt_item_md = md.Metadata(fc)
    if not tgt_item_md.isReadOnly:
        tgt_item_md.copy(new_md)
        tgt_item_md.save()

# Report elapsed time
for i in range(100000):
    i*i
elapsed_time = time.time() - start_time
minutes = elapsed_time // 60
seconds = elapsed_time % 60
print(f"This code block took {int(minutes)} minutes and {seconds:.2f} seconds to run")
# Out:
# This code block took 13 minutes and 7.73 seconds to run

# %% [markdown]
# # Create Topology Rules

# %%
# Add topology rules
start_time = time.time()
arcpy.Compact_management(thisDB) # often get schema lock here - this line seems to fix

featureClasses = [Boundary_py]
for feature in featureClasses:
    fc = feature
    arcpy.management.AddRuleToTopology(in_topology, "Must Not Have Gaps (Area)", fc, "", "", "")
    arcpy.management.AddRuleToTopology(in_topology, "Must Not Overlap (Area)", fc, "", "", "")

featureClasses = [Tracts_py]
for feature in featureClasses:
    fc = feature
    arcpy.management.AddRuleToTopology(in_topology, "Must Not Have Gaps (Area)", fc, "", "", "")
    arcpy.management.AddRuleToTopology(in_topology, "Must Not Overlap (Area)", fc, "", "", "")

featureClasses = [TractsBndy_ln]
for feature in featureClasses:
    fc = feature
    arcpy.management.AddRuleToTopology(in_topology, "Must Not Overlap (Line)", fc, "","", "")
    arcpy.management.AddRuleToTopology(in_topology, "Must Not Intersect (Line)", fc, "","", "")
    arcpy.management.AddRuleToTopology(in_topology, "Must Not Have Dangles (Line)", fc, "","", "")
    arcpy.management.AddRuleToTopology(in_topology, "Must Not Have Pseudo-Nodes (Line)", fc, "","", "")
    arcpy.management.AddRuleToTopology(in_topology, "Must Not Self-Overlap (Line)", fc, "","", "")
    arcpy.management.AddRuleToTopology(in_topology, "Must Not Self-Intersect (Line)", fc, "","", "")
    
arcpy.management.AddRuleToTopology(in_topology, "Boundary Must Be Covered By (Area-Line)", Boundary_py, "", TractsBndy_ln, "")
arcpy.management.AddRuleToTopology(in_topology, "Boundary Must Be Covered By (Area-Line)", Tracts_py, "", TractsBndy_ln, "")
    
# Report elapsed time
for i in range(100000):
    i*i
elapsed_time = time.time() - start_time
minutes = elapsed_time // 60
seconds = elapsed_time % 60
print(f"This code block took {int(minutes)} minutes and {seconds:.2f} seconds to run")
# Out:
# This code block took 0 minutes and 51.89 seconds to run

# %% [markdown]
# # Add Core Fields
# this block is 75% of of processing time (1 1/2 hrs)<br>
# toolbox much faster

# %%
# Add NPS GIS Core fields (takes forever - over 75% of total time here)
start_time = time.time()
arcpy.Compact_management(thisDB) # often get schema lock here - this line seems to fix

featureClasses = [
Boundary_py,
LegisHist_ln,
LegisHist_py,
SubsurfOwn_py,
SurfaceOwn_py,
Survey_py,
SurveyBndy_ln,
SurveyMon_pt,
Tracts_py,
TractsBndy_ln,
UseLocations_pt,
UseLocations_py,
UseLocations_ln
]

for feature in featureClasses:
    fc = feature
    arcpy.management.AddField(fc,"UNITCODE","TEXT","","",10,"UNITCODE","NULLABLE","NON_REQUIRED","")
    arcpy.management.AddField(fc,"MAPMETHOD","TEXT","","",254,"MAPMETHOD","NULLABLE","NON_REQUIRED","DOM_MAPMETHOD_LANDS2022")
    arcpy.management.AddField(fc,"MAPSOURCE","TEXT","","",254,"MAPSOURCE","NULLABLE","NON_REQUIRED","DOM_MAPSOURCE_LANDS2022")
    arcpy.management.AddField(fc,"SOURCEDATE","DATE","","","","SOURCEDATE","NULLABLE","NON_REQUIRED","")
    arcpy.management.AddField(fc,"XYACCURACY","TEXT","","",50,"XYACCURACY","NULLABLE","NON_REQUIRED","DOM_XYACCURACY_NPS2016")
    arcpy.management.AddField(fc,"NOTES","TEXT","","",254,"NOTES","NULLABLE","NON_REQUIRED","")
    arcpy.management.AddField(fc,"NOTES1","TEXT","","",254,"NOTES1","NULLABLE","NON_REQUIRED","")
    arcpy.management.AddField(fc,"DATAACCESS","TEXT","","",50,"DATAACCESS","NULLABLE","NON_REQUIRED","DOM_DATAACCESS_NPS2016")
    arcpy.management.AddField(fc,"PUBLICDISPLAY","TEXT","","",50,"PUBLICDISPLAY","NULLABLE","NON_REQUIRED","DOM_PUBLICDISPLAY_NPS2016")
    arcpy.management.AddField(fc,"ISEXTANT","TEXT","","",20,"ISEXTANT","NULLABLE","NON_REQUIRED","DOM_ISEXTANT_NPS2016")
    arcpy.management.AddField(fc,"EDITDATE","DATE","","","","EDITDATE","NULLABLE","NON_REQUIRED","")
    arcpy.management.AddField(fc,"EDITUSER","TEXT","","",50,"EDITUSER","NULLABLE","NON_REQUIRED","")
    arcpy.management.AddField(fc,"CREATEDATE","DATE","","","","CREATEDATE","NULLABLE","NON_REQUIRED","")
    arcpy.management.AddField(fc,"CREATEUSER","TEXT","","",50,"CREATEUSER","NULLABLE","NON_REQUIRED","")
    arcpy.management.AddField(fc,"LAYER","TEXT","","",254,"LAYER","NULLABLE","NON_REQUIRED","")
    arcpy.management.AddField(fc,"SOURCEFILE","TEXT","","",254,"SOURCEFILE","NULLABLE","NON_REQUIRED","")
    arcpy.management.AddField(fc,"MAPLABEL","TEXT","","",100,"MAPLABEL","NULLABLE","NON_REQUIRED","")
    
    # Set field default values
    arcpy.management.AssignDefaultToField(fc, "UNITCODE", unitCode, "", "")
    arcpy.management.AssignDefaultToField(fc, "DATAACCESS", "Internal NPS Only", "", "")
    arcpy.management.AssignDefaultToField(fc, "PUBLICDISPLAY", "No Public Map Display", "", "")
    arcpy.management.AssignDefaultToField(fc, "MAPMETHOD", "COGO", "", "")
    arcpy.management.AssignDefaultToField(fc, "MAPSOURCE","Document - Deed", "", "")
    arcpy.management.AssignDefaultToField(fc, "XYACCURACY", "Unknown", "", "")
    arcpy.management.AssignDefaultToField(fc, "ISEXTANT", "True", "", "")
    
# Report elapsed time
for i in range(100000):
    i*i
elapsed_time = time.time() - start_time
minutes = elapsed_time // 60
seconds = elapsed_time % 60
print(f"This code block took {int(minutes)} minutes and {seconds:.2f} seconds to run")
# Out:
# This code block took 75 minutes and 0.73 seconds to run

# %% [markdown]
# # Set Default Values

# %%
#   Set field default values
start_time = time.time()

featureClasses = [
Annotation_pt,
Annotation_ln,
Notes_pt
]

for feature in featureClasses:
    fc = feature
    arcpy.management.AssignDefaultToField(fc, "UNITCODE", unitCode, "", "")
    arcpy.management.AssignDefaultToField(fc, "DATAACCESS", "Internal NPS Only", "", "")
    arcpy.management.AssignDefaultToField(fc, "PUBLICDISPLAY", "No Public Map Display", "", "")
    
featureClasses = [
UseLocations_ln,
SurveyBndy_ln
]
for feature in featureClasses:
    fc = feature
    arcpy.management.EnableCOGO(fc)
    
# Database management stuff
arcpy.management.EnableEditorTracking(FD, "created_user", "created_date", "last_edited_user", "last_edited_date", "ADD_FIELDS", "UTC")
arcpy.management.AddGlobalIDs(FD)

# Autcalculate field FEATUREID's
# Tracts_py
arcpy.management.AddAttributeRule(Tracts_py, "ruleCalculateAlphaTract", "CALCULATION", "$feature.UNITCODE + '-' + $feature.TRACT_ID", "NONEDITABLE", "INSERT;UPDATE;DELETE", "", "", "", "", "FEATUREID", "", "", "", "")
# Boundary_py
arcpy.management.AssignDefaultToField(Boundary_py, "FEATUREID", areaID, "", "")
        
# Autocalculate CREATEUSER, CREATEDATE, EDITUSER, EDITDATE
featureClasses = [
Annotation_ln,
Annotation_pt,
Boundary_py,
LegisHist_ln,
LegisHist_py,
Notes_pt,
SubsurfOwn_py,
SurfaceOwn_py,
Survey_py,
SurveyBndy_ln,
SurveyMon_pt,
Tracts_py,
TractsBndy_ln,
UseLocations_pt,
UseLocations_py,
UseLocations_ln
]

# Report elapsed time
for i in range(100000):
    i*i
elapsed_time = time.time() - start_time
minutes = elapsed_time // 60
seconds = elapsed_time % 60
print(f"This code block took {int(minutes)} minutes and {seconds:.2f} seconds to run")
# Out:
# This code block took 3 minutes and 41.63 seconds to run

# %% [markdown]
# # End Script

# %%
print (dbPath, dbName+" created")
aprx.save()
# Out:
# E:\Parks\apro_projects\TestTemplate\ArcPro GOGA_Template created

# %%
# Leaving this here for future use if needed/wanted
# In lieu of autocalculating EDITUSER, EDITDATE, CREATEUSER, CREATEDATE  during the editing process
# Will calculate EDITUSER, EDITDATE, CREATEUSER, CREATEDATE during the publish process
# If/when data is received by WASO for the publish and there is no value in EDITUSER, EDITDATE, CREATEUSER or CREATEDATE
#  EDITUSER, EDITDATE, CREATEUSER, CREATEDATE will default to auto gdb last_edited_user, last_edited_date, created_user, created_date value if there is  
#for feature in featureClasses:
   # fc = feature
    #arcpy.management.AddAttributeRule(fc, "ruleCalculateCreateUser", "CALCULATION", "$feature.created_user", "EDITABLE", "INSERT;UPDATE;DELETE", "", "", "", "", "CREATEUSER", "", "", "", "")
    #arcpy.management.AddAttributeRule(fc, "ruleCalculateCreateDate", "CALCULATION", "$feature.created_date", "EDITABLE", "INSERT;UPDATE;DELETE", "", "", "", "", "CREATEDATE", "", "", "", "")
    #arcpy.management.AddAttributeRule(fc, "ruleCalculateEditUser", "CALCULATION", "$feature.last_edited_user", "EDITABLE", "INSERT;UPDATE;DELETE", "", "", "", "", "EDITUSER", "", "", "", "")
    #arcpy.management.AddAttributeRule(fc, "ruleCalculateEditDate", "CALCULATION", "$feature.last_edited_date", "EDITABLE", "INSERT;UPDATE;DELETE", "", "", "", "", "EDITDATE", "", "", "", "")
